# %% [markdown]
# # User Guide
#
# This is a experimental user guide to **Youcreep**.
#
# If you have any questions, please contact [steveflyer](steveflyer@gmail.com).

# %%
import logging

import nest_asyncio
import pandas as pd

from youcreep import YoutubeVideoInfoCrawler, YoutubeCommentCrawler
from youcreep.config.filter_enum import FilterSection, FilterLengthOption, FilterOrderByOption

nest_asyncio.apply()

# %% [markdown]
# ## 1. VideoInfo Crawler

# %%
# configure parameters
n_target = 50               # number of videos to crawl at most
search_term = "Python"      # search term
filter_config = {           # how to filter the search results, here we filter by view count and length
    FilterSection.ORDER_BY: FilterOrderByOption.VIEW_COUNT,
    FilterSection.LENGTH: FilterLengthOption.MEDIUM,
}

# call the crawler to crawl, we can use async with to make sure the crawler is closed after use
async with YoutubeVideoInfoCrawler(headless=False) as video_crawler:
    video_info_list = await video_crawler.crawl(
        search_term=search_term,
        n_target=n_target,
        filter_options=filter_config,
    )
    
video_info_list[:3]
# Out:
# [VideoInfo(video_id=dVRhRzE_AkQ),
#  VideoInfo(video_id=fr6WJG3Uw3M),
#  VideoInfo(video_id=XcxwOVNyfFY)]

# %% [markdown]
# The result of crawling is a list of dictionaries, you can easily convert it to a pandas dataframe.

# %%
video_df = pd.DataFrame([video_info.to_dict() for video_info in video_info_list])

video_df
# Out:
#        video_id                                              title  \
# 0   dVRhRzE_AkQ                                      Python的实惠美洲鳄鱼
# 1   fr6WJG3Uw3M  OMG! Capuchin Monkey Save Mouse From Banded Kr...
# 2   XcxwOVNyfFY  OMG! Giant Python Hunt Leopard Cubs When Mothe...
# 3   c98BHS8rSTg  Easy Snake Trap - Build Underground Python Tra...
# 4   adUlm2m7RrU  Stop Motion ASMR - Big Python eats Alligator G...
# 5   dw5eILfy-c8  Python is too aggressive, Lion Cub mistakes wh...
# 6   JgKN3BuvC3E     Python, Honey Badger & Jackal Fight Each Other
# 7   rLycYSY2V6Y                  10 Biggest Snakes Ever Discovered
# 8   5ADMawsgV5M                                      蜘蛛侠和斗牛犬对抗一只巨蟒
# 9   MRnORGSYGCQ  Primitive Survival 4K Video - Build PYTHON Hou...
# 10  _Z0pwIcSx2Y                                 柯尔特蟒蛇.357马格南打火机的修复
# 11  r5UCBPQF2ZI                            靛蓝蛇餐馆的Python 01 - 蛇同类相食
# 12  wPQzenQMxKs                          Python BITES and STRIKES!
# 13  5iK6FUMvTRQ  捉蛇大师设下重重陷阱，使出绝技把巨蟒缠成麻花！ 【变异巨蟒 Mutant Python】 |...
# 14  szlM0d2l6XQ  Spider-Man And Pitbull Dog Confront One Giant ...
# 15  g8ihwuiGKQ0  Don't let this wide-eyed doll see you move, or...
# 16  yCAPIynGgYo  Python Handler Becomes Victim To Snake Attack ...
# 17  gFPPwTSAZWw               Biggest Snakes Ever Caught On Camera
# 18  1jvvScb-D_8  Primitive Technology - Easy  Snake Trap With O...
# 19  9Vcc9cJP2hQ  GIANT ANACONDA SNAKE PYTHON TUMERIC SPICY WITH...
# 20  HX0fqtTJdeE  Top 15 Moments When Huge Snakes Eat Their Prey...
# 21  vewBjPfZ6ls                  KING COBRA EATS FLORIDA PYTHON!!!
# 22  0qiAUc06HJw                         Giant Python Bit My Face 😳
# 23  HpJ6PCbsI0M  15 Foot Python Gets Loose In Our House.. (TERR...
# 24  4JF6Uh0Xyrs  Python, Anaconda FIGHT over LIVE Squirrel -- E...
# 25  gP0xoRrf8i0        Anaconda Devours Huge Meal | Monster Snakes
# 26  k83fmb4iYnA  Python Too Aggressive, Leopard Cub Can't Escap...
# 27  virrOlgkjpQ  AKHIR MENEGANGKAN ULAR KING COBRA GOLDEN SANGG...
# 28  gyUZ1nUDaMY            GIANT SNAKE BITE + WRAPS HIM UP QUICKLY
# 29  yE0p0wclDqc  Giant Snake Soup - Delicious Big Python Boil F...
# 30  z_O1fG6Vwzg  Leo the Wildlife Ranger | HELP There is a Snak...
# 31  VY3PWZS1AIA  母子團聚不料卻被恐龍追擊！巨蛇朋友及時出現伸出援手【大蛇3：龍蛇之戰 Orochi 3: B...
# 32  ToNwDxVNQ_E                       Python Attack Compilation 01
# 33  UtNYzv8gLbs  Showing a Craigslist scammer who's boss using ...
# 34  k9WqpQp8VSU  How I Would Learn To Code (If I Could Start Over)
# 35  4f-w7rXMDyU                  10 Biggest Snakes Ever Captured !
# 36  dTX6f8HmkiU  GIANT PYTHON SNAKE Hunts Florida Swamps, Diora...
# 37  jiu0lYQIPqE  Monty Python's Eric Idle - London 2012 Perform...
# 38  box5GVnsfVE  Giant Python that stole honey was stung by the...
# 39  8RXPGbylsgg  Woman Sleeps With Snake Every Night, Until Doc...
# 40  zlZ_dupXxE0                              How to Hack Password?
# 41  hEgO047GxaQ  #1 Python Tutorial for Beginners | Introductio...
# 42  StmNWzHbQJU  Using My Python Skills To Punish Credit Card S...
# 43  jIbI23fvz5Y  A young man was attacked by a giant python whi...
# 44  rpa5900OpQ4  How to Learn Coding for Beginners [ Sharing My...
# 45  vOoIxoyuPUs  人蛇决战！大学生们遭到巨蟒猎杀，老头舍命引爆炸弹！【蛇岛狂蟒 Snake Island Py...
# 46  sN1vIxirO5E     World Record Burmese Python?! Prehistoric Pets
# 47  ZDa-Z5JzLYM                                 Python OOP教程1：类和实例
# 48  0WhAjw0Bmkw  Reticulated Python Needs Extra Help To Shed He...
# 49  9CddEykqaKk  The Bounty Hunters Catching Pythons In Florida...
# 50  mbryl4MZJms  #2 Python Tutorial for Beginners | Python Inst...
# 51  H9PY_3E3h2c                   Monty Python Deductive Reasoning
# 52  DWgzHbglNIo  #3 Python Tutorial for Beginners | Getting Sta...
# 53  9s29LKfEFjQ  How I would learn to code (If I could start over)
# 54  kLZuut1fYzQ  What Can You Do with Python? - The 3 Main Appl...
# 55  -VDXBHLU8q4  How I Learned to Code in 4 MONTHS & Got a Job ...
#
#                                       video_url  is_short view_count  \
# 0   https://www.youtube.com/watch?v=dVRhRzE_AkQ     False    1.5亿次观看
# 1   https://www.youtube.com/watch?v=fr6WJG3Uw3M     False    1.5亿次观看
# 2   https://www.youtube.com/watch?v=XcxwOVNyfFY     False    1.4亿次观看
# 3   https://www.youtube.com/watch?v=c98BHS8rSTg     False    1.4亿次观看
# 44  https://www.youtube.com/watch?v=rpa5900OpQ4     False    438万次观看
# 45  https://www.youtube.com/watch?v=vOoIxoyuPUs     False    417万次观看
# 46  https://www.youtube.com/watch?v=sN1vIxirO5E     False    411万次观看
# 47  https://www.youtube.com/watch?v=ZDa-Z5JzLYM     False    406万次观看
# 48  https://www.youtube.com/watch?v=0WhAjw0Bmkw     False    399万次观看
# 49  https://www.youtube.com/watch?v=9CddEykqaKk     False    364万次观看
# 50  https://www.youtube.com/watch?v=mbryl4MZJms     False    362万次观看
# 51  https://www.youtube.com/watch?v=H9PY_3E3h2c     False    361万次观看
# 52  https://www.youtube.com/watch?v=DWgzHbglNIo     False    351万次观看
# 53  https://www.youtube.com/watch?v=9s29LKfEFjQ     False    346万次观看
# 54  https://www.youtube.com/watch?v=kLZuut1fYzQ     False    345万次观看
# 55  https://www.youtube.com/watch?v=-VDXBHLU8q4     False    340万次观看
#
#    publish_time          channel_name  \
# 0          11年前                ojatro
# 1           4年前       Life Of Big Cat
# 2           3年前       Life Of Big Cat
# 3           3年前                 da ra
# 4           2年前       Unusual Cooking
# 5           4年前            Alan Tours
# 6           3年前          Caters Video
# 7           2年前              FactFile
# 8           1年前      King Of Survival
# 9           3年前  Survival Skills Asia
# 10          2年前  Awesome Restorations
# 11          8年前                ojatro
# 12          7年前      Brave Wilderness
# 13          1年前                 经典大本营
# 14          1年前           King Python
# 15          1年前       Python Recapped
# 16         10年前         Animal Planet
# 17         9个月前                Max TV
# 18          1年前          PLENG KOMSAN
# 19          2年前     The Young's Story
# 20          1年前         The Brilliant
# 21          4年前  Chandler's Wild Life
# 22          2年前    JayPrehistoricPets
# 23          3年前       The LaBrant Fam
# 24          4年前       Reptile Channel
# 25          4年前          Nat Geo WILD
# 26          2年前   Wild Animals Things
# 27          2年前       Manda petualang
# 28          4年前   New England Reptile
# 29          3年前       Wilderness Food
# 30          2年前        Mediacorp okto
# 31         9个月前                 奇妙影视馆
# 32          9年前                ojatro
# 33          5年前          Engineer Man
# 34          1年前          Namanh Kapur
# 35          2年前          4 Ever Green
# 36         5个月前         Emz Odd Works
# 37         11年前              Olympics
# 38         9个月前           UFO ANIMALS
# 39          1年前        Did You Know ?
# 40          1年前          Apna College
# 41          5年前               Telusko
# 42          2年前          Engineer Man
# 43        10个月前         Hunter Boy TV
# 44          3年前       Technology Gyan
# 45        10个月前                 经典大本营
# 46          2年前    JayPrehistoricPets
# 47          7年前         Corey Schafer
# 48          4年前         Animal Planet
# 49          4年前             VICE News
# 50          5年前               Telusko
# 51         11年前       ReggieNetCom110
# 52          5年前               Telusko
# 53          1年前        Jason Goodison
# 54          5年前               CS Dojo
# 55          1年前   Internet Made Coder
#
#                                        channel_url  \
# 0                  https://www.youtube.com/@ojatro
# 1        https://www.youtube.com/@lifeofbigcat2374
# 2        https://www.youtube.com/@lifeofbigcat2374
# 3              https://www.youtube.com/@dara-ee4uv
# 4          https://www.youtube.com/@UnusualCooking
# 5             https://www.youtube.com/@Alantours4u
# 6             https://www.youtube.com/@CatersVideo
# 7                https://www.youtube.com/@FactFile
# 8     https://www.youtube.com/@KingOfSurvivalVlogs
# 9      https://www.youtube.com/@survivalskillsasia
# 10    https://www.youtube.com/@AwesomeRestorations
# 11                 https://www.youtube.com/@ojatro
# 12        https://www.youtube.com/@BraveWilderness
# 13        https://www.youtube.com/@classicmoviesCN
# 14           https://www.youtube.com/@KingPythontv
# 15         https://www.youtube.com/@PythonRecapped
# 16           https://www.youtube.com/@animalplanet
# 17              https://www.youtube.com/@maxtv7944
# 18        https://www.youtube.com/@plengkomsan5606
# 19         https://www.youtube.com/@TheYoungsStory
# 20       https://www.youtube.com/@thebrilliantarmy
# 21      https://www.youtube.com/@ChandlersWildLife
# 22   https://www.youtube.com/@JayPrehistoricPetsTV
# 23             https://www.youtube.com/@ColeAndSav
# 24         https://www.youtube.com/@ReptileChannel
# 25             https://www.youtube.com/@NatGeoWild
# 26        https://www.youtube.com/@blessedbaritone
# 27         https://www.youtube.com/@Mandapetualang
# 28      https://www.youtube.com/@NewEnglandReptile
# 29  https://www.youtube.com/@WildernessFoodCooking
# 30          https://www.youtube.com/@Mediacorpokto
# 31        https://www.youtube.com/@Fantastic-movie
# 32                 https://www.youtube.com/@ojatro
# 33            https://www.youtube.com/@EngineerMan
# 34            https://www.youtube.com/@namanhkapur
# 35           https://www.youtube.com/@4EverGreenYT
# 36            https://www.youtube.com/@emzoddworks
# 37               https://www.youtube.com/@Olympics
# 38         https://www.youtube.com/@ufoanimals5557
# 39                    https://www.youtube.com/@DUK
# 40    https://www.youtube.com/@ApnaCollegeOfficial
# 41                https://www.youtube.com/@Telusko
# 42            https://www.youtube.com/@EngineerMan
# 43         https://www.youtube.com/@hunterboytv433
# 44         https://www.youtube.com/@TechnologyGyan
# 45        https://www.youtube.com/@classicmoviesCN
# 46   https://www.youtube.com/@JayPrehistoricPetsTV
# 47                https://www.youtube.com/@coreyms
# 48           https://www.youtube.com/@animalplanet
# 49               https://www.youtube.com/@VICENews
# 50                https://www.youtube.com/@Telusko
# 51        https://www.youtube.com/@ReggieNetCom110
# 52                https://www.youtube.com/@Telusko
# 53          https://www.youtube.com/@JasonGoodison
# 54                 https://www.youtube.com/@CSDojo
# 55      https://www.youtube.com/@InternetMadeCoder
#
#                                             desc_text
# 0   网址：http://Ojatro.com\nFacebook的：https://www.fa...
# 1   OMG! Capuchin Monkey Save Mouse From Banded Kr...
# 2   OMG! Giant Python Hunt Leopard Cubs When Mothe...
# 3   Easy Snake Trap - Build Underground Python Tra...
# 4   Hello my dear viewers, Unbelievable Fishing at...
# 5   NAP , #NAPanimal Python is too aggressive, Lio...
# 6   ID: 3331461 MANDATORY ONSCREEN CREDIT - Rosely...
# 7   There are over 3000 species of snake on the pl...
# 8                                       蜘蛛侠和斗牛犬对抗一只巨蟒
# 9   Primitive Survival 4K Video - Build PYTHON Hou...
# 10  柯尔特蟒蛇.357马格南打火机的修复 我将修复这个看起来很酷的左轮手枪打火机并让它再次工作。...
# 11  网址：http://Ojatro.com\nFacebook的：https://www.fa...
# 12  On this episode of Breaking Trail, Coyote spot...
# 13  电影名：变异巨蟒 Mutant Python 简介：闭塞的闽北山村长生村中，三房家长董兆如却...
# 14  Only 1% people in the world could pass this ga...
# 15  #film #movie #moviereview #story DISCLAIMER: T...
# 16  After capturing a python, the snake bites his ...
# 17  Гигантские змеи Мало у кого змеи вызывают симп...
# 18  Primitive Technology - Easy Snake Trap With Ol...
# 19  indonesianfood #extremefood #eatingsnake The Y...
# 20  Snakes are powerful and stealthy predators tha...
# 21  We feed wild-caught Burmese pythons to Kevin t...
# 22  Well... This is the video you've been waiting ...
# 23  Follow Jay on Instagram too! @JayPrehistoricPe...
# 24  Giant snakes discover a squirrel--battle as sq...
# 25  #NatGeoWILD #Anacondas #Snakes About National ...
# 26  Python Too Aggressive, Leopard Cub Can't Escap...
# 27  AKHIR MENEGANGKAN SAAT ULAR KING COBRA GOLDEN ...
# 28  Twitch Livestreams! http://twitch.tv/newenglan...
# 29  Giant Snake Soup - Delicious Big Python Boil F...
# 30  The Junior Rangers find a python in a very unu...
# 31  片名：【大蛇3：龍蛇之戰 Orochi 3: Battle of Dragon Snake】...
# 32  Many pythons escaped into the swamps of the Ev...
# 33  Some silly Craigslist scammer thinks he's gonn...
# 34  If I could go back in time and learn to code, ...
# 35  Of the over 600 species of venomous snakes on ...
# 36  burmesepython #everglades #sculpture #art #mon...
# 37  Monty Python's Eric Idle performs 'Always Look...
# 38  Giant Python that stole honey was stung by the...
# 39  Woman Sleeps With Snake Every Night, Until Doc...
# 40  Are you worried about placements/internships? ...
# 41  In this lecture we will learn: - Why Python is...
# 42  Here we go again, another day, another scammer...
# 43  A young man was attacked by a giant python whi...
# 44  How to learn coding ? coding kaise sikhe well ...
# 45  片名：【蛇岛狂蟒 Snake Island Python】 简介：《蛇岛狂蟒》讲述了风景秀美...
# 46  Is this the biggest Burmese python in the worl...
# 47  在这个Python面向对象的教程中，我们将通过学习如何在Python中创建和使用类来开始我们...
# 48  It's time for Cleo the reticulated python to s...
# 49  The Everglades in Florida are plagued with doz...
# 50  In this video we will see : - Download and ins...
# 51
# 52  In this lecture we will learn: - How operation...
# 53  Starting in Special Ed and ending at Microsoft...
# 54  What is Python used for? What can you do with ...
# 55  How I became a self-taught Software Engineer &...

# %% [markdown]
# ## 2. Comment Crawler

# %%
from gembox.debug_utils import ConsoleDebugger

# configure parameters
# test_video_url = video_df.video_url[0]
test_video_url = "https://www.youtube.com/watch?v=c98BHS8rSTg"
n_target = 50

# call the crawler to crawl, this time, we use headless mode to avoid opening a browser, and we enable detailed logging to trace the crawling process
async with YoutubeCommentCrawler(headless=True, debug_tool=ConsoleDebugger(level=logging.INFO)) as comment_crawler:
    comment_list = await comment_crawler.crawl(
        video_url=test_video_url,
        n_target=n_target,
    )
comment_df = pd.DataFrame([comment.to_dict() for comment in comment_list])

comment_df
# Out:
# 2023-08-21 16:23:15,408 - gembox.debug_utils_21c7_logger - INFO - Browser: Go to https://www.youtube.com/
# 2023-08-21 16:23:17,118 - gembox.debug_utils_21c7_logger - INFO - Browser: Go to https://www.youtube.com/watch?v=c98BHS8rSTg
# 2023-08-21 16:23:19,080 - gembox.debug_utils_21c7_logger - INFO - Scrolling and loading ytd-comment-renderer...
# 2023-08-21 16:23:19,081 - gembox.debug_utils_21c7_logger - INFO - Inner Call Scrolling and loading...(selector=ytd-comment-renderer, scroll_step=400, load_wait=40, same_th=100, threshold=50)
# 2023-08-21 16:23:19,181 - gembox.debug_utils_21c7_logger - INFO - Top unchanged, Scroll top: 189, last top: 189, same count:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 3. Multiprocessing Crawler

# %% [markdown]
# You can easily crawl multiple videos or comments in parallel using multiprocessing.
#
# The calling methods just receive a list of parameters, and you can specify `n_workers` to control the number of parallel processes.

# %% [markdown]
# ### Crawl video info from a list of search terms

# %%
# configure parameters
search_terms = ["OpenAI", "Deep Learning", "Machine Learning", "Artificial Intelligence", "AI", "Neural Network", "Reinforcement Learning"]
n_targets = [20] * len(search_terms)

# call the crawler to crawl
await YoutubeVideoInfoCrawler.parallel_crawl(
    search_term_list=search_terms,
    n_target_list=n_targets,
    n_workers=4,                        # number of workers, i.e. number of parallel processes
    output_dir="youtube_output/search", # output directory
)

# %% [markdown]
# #### Check the output

# %%
video_csv = "youtube_output/search/AI_20_video_info.csv"  # change the file name to the one you just crawled
video_df = pd.read_csv(video_csv, index_col=0)

video_df
# Out:
#        video_id                                              title  \
# 0   Pj8pKvRdMIw         【財富的第N本筆記】AI股引爆台股！下一個引爆的概念股是「它」@CtiFinance
# 1   xUurLG5euDY           一鍵變臉! AI軟體扮公安 可邊換臉邊直播｜TVBS新聞 @TVBSNEWS01
# 2   1B0OPbaSSH8               網瘋傳AI繪「蠟筆小新島」　超級逼真有房有海｜華視新聞 20230820
# 3   XQQjMtOfgpo  【 8 月 AI 新聞精選】ChatGPT 5 新一代 AI 已註冊  多款 AI 難敵中國...
# 4   X9MM9vctavM  REACTION AI TEAM NISAA PREGNANT???? AFIQ MENAN...
# 5   v4_TTKzfMHA  FIRST IMPRESSION AI TEAM TERHADAP SYAHMIE??? S...
# 6   3QjlrITaAMQ  【理財達人秀】AI股大跌能撿？杜金龍獨家算目標價！官股.投信國家隊護盤 跟單誰？恆大破產人行...
# 7   PCHskDuG2mw  AI孫燕姿歌曲30首精選，每首歌曲都是最高音質！快來聽你最喜歡的歌曲吧！AI Stefani...
# 8   L51HuFs-D10  PRANK BALING PHONE KANDA MIMI !!! FARIDAH KENA...
# 9   uTryDiddEck  SENIOR AI TEAM AJAR MADKHAN CARA UNTUK PIKAT H...
# 10  47ROmH42unA  KANDA MINTAK MAAF KAT MIMI !! FIERA MARAH ANIQ !!
# 11  9OJFq9gQ0pE                 太誇張了😱AI三秒鐘完成修圖 Photoshop最新功能 生成式AI
# 12  HMCexp4cPIo  麥肯錫推自家AI諮詢顧問 高知識工作者變就業輸家！？| 金臨天下 20230818  @tv...
# 13  AeiLpDJaoGE  【哥有籌必爆S2】第21集！｜韭菜自救！扭轉被倒貨 小心主力高檔出貨訊號｜李兆華、權證小哥《...
# 14  ArkqATD1vDE        [4K AI Art] "Does pink suit me?" 💗#lookbook
# 15  yhOACkeuq8M  [80分鐘串燒系列 80 Minutes NonStop] 那些年我們聽過的歌 (2001-...
# 16  vT54wNB4DM4  復旦人工智能教授：未來3-5年，哪些工作會被AI取代？Fudan AI Professor ...
# 17  1mR75CIXO_I           外資喊話挺AI 台積電降財測潑冷水？｜股市全威 陳威良 分析師｜20230821
# 18  VQjPKqE39No             How Will We Know When AI is Conscious?
#                                             desc_text
# 0   AI股讓台股紅紅火火，雖然是幾家歡樂幾家愁，甚至讓緯創的股價爬上百元俱樂部，相信讓不少投資人...
# 1   持續追蹤這起詐騙案，詐騙集團利用AI變臉軟體，鎖定海外人士詐騙，甚至可以一邊變臉一邊直播，但...
# 2   您有聽過「蠟筆小新島」嗎？最近外觀神似小新和小白的島嶼空拍照，在網路上瘋傳，不少人說實在好想...
# 3   OpenAI 被發現為「GPT- 5」商標申請，新一代AI 已經開發中? 想知更多就要即刻睇...
# 4                                                 NaN
# 5   HI CITY BOY HERE so content kali ni saya nak t...
# 6   在小賈身編：鴻海低點到可接？ #AI #儲能#台股#理財達人秀(00:00) 航海王乘風破浪...
# 7   00:00:00【AI孫燕姿】《安靜》翻唱周杰倫00:05:16【AI孫燕姿】《被動》 00...
# 8   Hidup ni kita kena santaiii... Walaupon kita j...
# 9   SO KORANG DAH TENGOK KAN MAD DAH MINTAK TIPS U...
# 10  KENING TEBAL !! Video ini hanyala hiburan sema...
# 11  Instagram: @apple_meii - 關於我 - 哈囉！我是蘋果妹，來自臺灣，這...
# 12  麥肯錫#AI #諮詢顧問✓密切鎖定【金臨天下】快來訂閱➔https://bit.ly/3rm...
# 13  在小賈身編：如何看穿主力手法？ #集保戶數#主力#哥有籌必爆#理財達人秀本節目與分析師所推介...
# 14  Today, we are trying on various styles of vibr...
# 15  在那個mp3才在開始崛起的年代，CD是我們聽歌的方式。 也就因為CD的時長只有80分鐘的限制...
# 16  今年5月1日當天，第一波AI失業潮到來，科技巨頭IBM公司宣布暫停7800人的招聘，稱這些崗...
# 17  本節目與分析師所推介個股，無不當之財務利益關係，資料僅供參考，投資人應獨立判斷，審慎評估並自...
# 18  Siri, write this down immediately. "A movie wh...
# 19  這支影片試著把AI 的相關歷史、技術背景、延伸應用以及該如何去看待AI 的發展，以容易理解的...
# 20  有人工智能（AI）「教父」之稱的傑弗里·辛頓（Geoffrey Hinton）早前辭去在Go...
# 21  本節目與分析師所推介個股，無不當之財務利益關係，投資人應獨立判斷，審慎評估並自負投資風險。 ...
# 22  這些天,我們幾乎可以在你的沙發上虛擬參觀劇院,觀賞不同的表演並看看博物館的展品。 而且,如果...
# 23  新進展！ 馬斯克二次官宣Neuralink將開啟人體試驗今天科技界的大新聞又是來自馬斯克同學...
# 24  各節重點： 00:53 什麼是物聯網 01:48 日常生活中有智慧的物件 03:26 智慧交...
# 25  Power Point可以被取代嗎？近期做簡報基本上已經不再使用Power Point，原因...
# 26  □-------------------------------------- 00:00 ...
# 27  黃仁勳#AI教父#輝達有AI教父之稱的輝達創辦人暨執行長黃仁勳，在台掀起一陣旋風，29日他前...
# 28  早在去年7月中旬，馬斯克宣布已經成功通過腦機接口技術，將自己的意識上傳到雲端，而新一輪AI大...
# 29  英國科技公司研發AI人形機器人，它回話方式自然流暢，還有皺眉、微笑等多種表情，比過去的機器人...

# %% [markdown]
# ### Crawl comments from a list of video urls

# %%
# get testing video_urls from the data we just crawled
video_urls = video_df["video_url"].tolist()

# configure parameters
video_urls = video_urls[:5]  # we just crawl comments from the first 5 videos to avoid long waiting time
n_targets = [30] * len(video_urls)  # we crawl 30 comments at most from each video

# call the crawler to crawl
await YoutubeCommentCrawler.parallel_crawl(
    video_url_list=video_urls,
    n_target_list=n_targets,
    n_workers=4,                        # number of workers, i.e. number of parallel processes
    output_dir="youtube_output/comment", # output directory
)

# %% [markdown]
# #### Check the output

# %%
comment_csv = "youtube_output/comment/X9MM9vctavM_30_comment.csv"  # change the file name to the one you just crawled
comment_df = pd.read_csv(comment_csv, index_col=0)

comment_df
# Out:
#                     comment_id  is_reply              author_name  \
# 0   Ugy-pt3ecAMZdKhnJHd4AaABAg     False               @Zahirah12
# 1   UgzeFm1mx0ET4ZD66rB4AaABAg     False            @kritta_v1025
# 2   UgxP3_hLXxgF5wijC4B4AaABAg     False             @itsyaff7280
# 3   Ugx5R5h4PqvSgdiV6tl4AaABAg     False         @fatinnajiha5788
# 4   UgxFzQ0-x5NjVmZoXR54AaABAg     False      @fansaliefirfanteam
# 5   UgxUQqICQYyiIzvdil94AaABAg     False        @boseychannel8024
# 6   UgwHBx478Btb6BP_uqF4AaABAg     False            @muhdsany5929
# 7   Ugwfv3zWfN30Xs_gjOF4AaABAg     False              @asmiemie87
# 8   Ugz0CpvHwIAEH7IQBsF4AaABAg     False         @nuramirazhar984
# 9   Ugw2bJhtV37zZcofJ-l4AaABAg     False         @Lesslayrafim134
# 10  UgyRC8BTNlT7HHDAWDt4AaABAg     False            @pinky._ayana
# 11  UgyGcejlqcRBjioXUfB4AaABAg     False           @dayahnoor1328
# 12  UgzKyNawXOHZlFmvUUl4AaABAg     False          @shaugialatas31
# 13  UgzORLR3WzRleOy8Grl4AaABAg     False          @sarahsyazana93
# 14  UgyRVQMPRmGiscvmr394AaABAg     False          @itswzspace9925
# 15  Ugyr1tMpGwhQMSXObRB4AaABAg     False      @dinaaddreanarasidi
# 16  Ugy5A19jvsxtKkVBPaN4AaABAg     False              @puanezum94
# 17  UgxN8V8Bepvr2rW_RHR4AaABAg     False  @khalilahbadrulshah3265
# 18  UgytBqfPRaxMz0mnX_V4AaABAg     False              @pijonnn077
# 19  UgzQRSC29HXXC-WxTH94AaABAg     False       @mohdaliffnadwan44
# 20  UgzKY9QvMkAmFD5iudR4AaABAg     False       @salizasahidan4654
# 21  UgwEthtXk5Viuu5CR8l4AaABAg     False           @pikahyana8020
# 22  UgzZFfp5WzNOFFJbIDB4AaABAg     False          @sopiekadri9924
# 23  UgygJxXHFPzWyC3CTZF4AaABAg     False           @hidayat-zw5ef
# 24  UgwGHar312VpUqavlW54AaABAg     False         @mohdmarzuki6418
# 25  Ugzb-81rg6RBn9mfaAN4AaABAg     False        @afiqahafiqah5344
# 26  UgzQb96Vi-5oxrp2IUR4AaABAg     False             @iramimo4755
# 27  UgzXJjfo9bfWPC16wz54AaABAg     False    @rejabtulbaharuddin52
# 28  UgwERHcMyul6qR2bLO54AaABAg     False          @yantiahmad3104
# 29  Ugw4Rya62ZPOBouqPnJ4AaABAg     False          @mohdamirul9930
# 30  Ugw5da9dg5uHEmSg1S94AaABAg     False             @SuzilaIsyak
# 31  Ugz4n7V1Pkuw-W5pRwZ4AaABAg     False    @norlizaabdrahman8420
# 32  Ugyj49TCLwiuXDc32z14AaABAg     False           @heyyoziee4162
# 33  Ugzpx7iPo-MC8kumxoR4AaABAg     False         @wadamustafa7309
# 34  UgyrfVibpgSucej8oOl4AaABAg     False             @77__atok_56
# 35  UgzGWD2jNmFeS8LRjAx4AaABAg     False        @hanaaasalehhudin
# 36  UgzGMLCCzGLW9AyPTzx4AaABAg     False        @zurinahnudin2772
# 37  Ugxz367e_c7KOH846hZ4AaABAg     False       @shatirahjuman2955
# 38  UgyA7cxvstLDJhT2TB14AaABAg     False           @aishahazmi01_
# 39  UgwiXhFrG6Z9dJB1iLh4AaABAg     False              @AlimGlobeR
#
#                            author_url  publish_time  parent_comment_id  \
# 0   /channel/UCpAZNibWG4EPdje0CYczw4A        16 小時前                NaN
# 1   /channel/UCiehePtwUNvp-X6J4GaQwHg        15 小時前                NaN
# 2   /channel/UCkKvXhWqvlyJ37b2L4qu_3A         1 小時前                NaN
# 3   /channel/UCs5nhKcc4ng9OCxKhH5YM7g   7 小時前 (已編輯)                NaN
# 4   /channel/UCz9EX3Eo4CRFIfk5HqyeXjQ        17 小時前                NaN
# 5   /channel/UCAHM0yG3HQrU2aTd3Yi5_bw  16 小時前 (已編輯)                NaN
# 6   /channel/UC6DmM9ovCd0k9yoDg7tY-hg        16 小時前                NaN
# 7   /channel/UC-DkbMs-Q2aTC7rn7mSlbLA        17 小時前                NaN
# 8   /channel/UCz9-KgGjidyuQFpqlkWufzA         5 小時前                NaN
# 9   /channel/UCK2WpI5zAPvAUegMKwKG2BQ        17 小時前                NaN
# 10  /channel/UC1QuGoSPB53UhCN0R5aYayg         8 小時前                NaN
# 11  /channel/UCJ9V1w6KTSw5ZiTmXG3ALzQ        17 小時前                NaN
# 12  /channel/UC9fZXqy91XTqpHXXa-TTPRg        17 小時前                NaN
# 13  /channel/UCsxrkFtgmRy28rsidWXqmIw   1 小時前 (已編輯)                NaN
# 14  /channel/UCgTFtbQ2VuUtpwUxKdHzLRw        17 小時前                NaN
# 15  /channel/UCW3HvYHMKF7O2zeYq53Q0DQ        16 小時前                NaN
# 16  /channel/UCXdsNaLjsOa6mE33h3jI7wA         7 小時前                NaN
# 17  /channel/UCTD49rkd1J9_yh4DnEnp8DA  17 小時前 (已編輯)                NaN
# 18  /channel/UCpF3xSTX4HdydHpnsRhKXAQ        16 小時前                NaN
# 19  /channel/UChhEx9OIBUKYeTd7IsSOeNA        10 小時前                NaN
# 20  /channel/UC-6QX9oUKeLnfRipBMkmwKA        16 小時前                NaN
# 21  /channel/UC2qxruNL9Ayi4WjLXhWhW0Q        17 小時前                NaN
# 22  /channel/UCPFb98EmHSN6kZN0VnhcXFw        17 小時前                NaN
# 23  /channel/UCxgG2mRhh7E-Ay8TOhG1YJA        17 小時前                NaN
# 24  /channel/UCiuxMYO0VibQjSByH9w7F_g         8 小時前                NaN
# 25  /channel/UC-RIjTDNecs6-quSw6zqx8w        17 小時前                NaN
# 26  /channel/UCQivgwDvaYLy-dMQWL-mulw  17 小時前 (已編輯)                NaN
# 27  /channel/UCtYxg8Ppd7sSbauNrG_BsTg        17 小時前                NaN
# 28  /channel/UC0e5iX9Fqp8PAVLfdodhHOg        16 小時前                NaN
# 29  /channel/UCT1HmVjbLr2l6yuYzmhra1Q        15 小時前                NaN
# 30  /channel/UCG05FRQdCYJdk1WJBjO9hjA         2 小時前                NaN
# 31  /channel/UC_nNgiux7Wb9SxDHN0xF0Kw         4 小時前                NaN
# 32  /channel/UCm4kksbOZzcZq9yMT-lLzfw         4 小時前                NaN
# 33  /channel/UCXIl97v1FuOazDIEhUxIShw         7 小時前                NaN
# 34  /channel/UCFyakW8Lt4Fm35EG6Um13gw        16 小時前                NaN
# 35  /channel/UC6rryzngh9oeAoXzj8dTSKw         1 小時前                NaN
# 36  /channel/UCkLGC-0G-qDZ8HUGaeQb4pg        16 小時前                NaN
# 37  /channel/UCblSagWE4yZrHRAiwe_MacQ        17 小時前                NaN
# 38  /channel/UCWWyoyhJFTb5VC2BDyEdnmw        17 小時前                NaN
# 39  /channel/UCX8ZjJpQ6wDM1b25FS0cfsA        15 小時前                NaN
#
#        video_id                                   author_thumbnail  \
# 0   X9MM9vctavM  https://yt3.ggpht.com/eUX9dK2-xAF7RZMnCNFwKVu1...
# 1   X9MM9vctavM  https://yt3.ggpht.com/KxmPP0H70aXTyXETiWBCewp7...
# 2   X9MM9vctavM  https://yt3.ggpht.com/q1tY6lZaOgTbFqwV3xfSikUW...
# 3   X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaTIrHTpGYdhipCY...
# 4   X9MM9vctavM  https://yt3.ggpht.com/LDzLxxGe32JZjjo81yQjYaHZ...
# 5   X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaTtXiCdh__RL-xi...
# 6   X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaQX-6rcdUAycs_K...
# 7   X9MM9vctavM  https://yt3.ggpht.com/pIdq8uRu7vqWHYIr5K2RNTKn...
# 8   X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaSM9spboeovun6h...
# 9   X9MM9vctavM  https://yt3.ggpht.com/amZRuTJ-RAaUEmtojJi9PeQc...
# 10  X9MM9vctavM  https://yt3.ggpht.com/qvM8sdwrOPlk1vOVt9SqrPEN...
# 11  X9MM9vctavM  https://yt3.ggpht.com/0EYI3BJC-mpNZEtPou5Fgy8j...
# 12  X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaSiyLNukeaidI-b...
# 13  X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaR-9PtvlsT5S6KP...
# 14  X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaR-V3MuVGf8xYay...
# 15  X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaSH1nbXW2VxrrQb...
# 16  X9MM9vctavM  https://yt3.ggpht.com/MfOw0a4nh246VrJSGcUbnNOg...
# 17  X9MM9vctavM  https://yt3.ggpht.com/a1EFPxAE8H196HefLSo2HxmP...
# 18  X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaTztcC7VgD63oWI...
# 19  X9MM9vctavM  https://yt3.ggpht.com/qzhnxiCehTierq5VIboVhKK1...
# 20  X9MM9vctavM  https://yt3.ggpht.com/tVnZz1SanqtOD-nQx6aDyxPm...
# 21  X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaS-9y1KH-rvtOTF...
# 22  X9MM9vctavM  https://yt3.ggpht.com/oPm9KHlgSLNXGiEByoDK2zwD...
# 23  X9MM9vctavM  https://yt3.ggpht.com/ytc/AOPolaS7IiTb2suCbumB...
# 24  X9MM9vctavM                                                NaN
# 25  X9MM9vctavM                                                NaN
# 26  X9MM9vctavM                                                NaN
# 27  X9MM9vctavM                                                NaN
# 28  X9MM9vctavM                                                NaN
# 29  X9MM9vctavM                                                NaN
# 30  X9MM9vctavM                                                NaN
# 31  X9MM9vctavM                                                NaN
# 32  X9MM9vctavM                                                NaN
# 33  X9MM9vctavM                                                NaN
# 34  X9MM9vctavM                                                NaN
# 35  X9MM9vctavM                                                NaN
# 36  X9MM9vctavM                                                NaN
# 37  X9MM9vctavM                                                NaN
# 38  X9MM9vctavM                                                NaN
# 39  X9MM9vctavM                                                NaN
#
#                                          content_text  like_count
# 0   Tak tau nk ckp mcm mana. The best reaction yg ...         347
# 1   ikut terharu liatnya, persahabatan mereka kuat...         104
# 2   suka tengok friendship diorang. dari zaman buj...           9
# 3   Alhamdulilah semoga boy & nisa dimurahkn rezek...          20
# 4   Congrats Boy & Nisa   Semoga Sentiasa Dipermud...          66
# 5   YES!! konten yg dinantikan, reaction drpd ai t...         105
# 6   Alhamdulillah …tahniah boy&nisa…semoga Allah p...          44
# 7   Tahniah boy dan Nisa..Alhamdulillah doa² kami ...          62
# 8   Alhamdulillah , terharu tengok persahabatan di...          11
# 9   Terharu tgk persahabatan ai team A dari dulu s...         131
# 10  Suka btul tgok friendship diorg ni msing² happ...          10
# 11  Ya Allah sukanya tgk friendship AI Team ️ semo...          34
# 12  semoga Nissa kehamilan selalu sehat-sehat teru...          58
# 13  Alhamdulillah terharu tengok persahabatan dior...           4
# 14  Priceless gilaa reaction afiq. Allahu tahniah ...         126
# 15  Seronok tengok friendship dorangg sampai kitaa...          82
# 16  Sebak pulak tengok.bahagia tengok masing2 dh n...           6
# 17  Alhamdulillah tahniah boy n nisa..sebaknye... ...          25
# 18  dapat persahabatan mcm ni pon salah 1 rezeki t...          21
# 19  Alhamdulillah syukur . Suke tengok friend ship...           6
# 20  alhamdulillah tahniah boy n nisa.jaga kandunga...          52
# 21  Semoga nisa & kandungan baik² sajaseronok teng...          18
# 22  Tahniah boy... Semoga korang suami isteri siha...          83
# 23  alhamdulillah semoga boy dan nisa sentiasa dib...          22
# 24  tahniah boy dgn nisa..alhamdulillah , sis pon ...           2
# 25           terharu nyaaa tengok persahabatan depaa           11
# 26  Tahniah, nanti anak2 team A semua sebaya je bo...          15
# 27  Tahniah boy and Nisa semoga Allah SWT melindun...          22
# 28  Sebak tengok antara mereka rapat seperti kelua...           2
# 29  Sumpah wehhh mmg aku jeles+terharu dgn vibe fr...           5
# 30  Alhamdulillah...terharu n happy  utk boy n nis...           1
# 31  Kak ikot terharu jatuh air mata melihat hbunga...           2
# 32  Sumpah terharu tgok persahabatan ai . Memang d...           2
# 33  Ya Allah, suka betul tngk persahabatan dorg ni...           3
# 34  Xsabar menanti saat² harinya yg bersejarah unt...          11
# 35  Congrats boyyy . Semua senior yg kawen alhamdu...           0
# 36  Assalamualaikum🇧🇳🇧🇳.. ini lah erti persahabata...          10
# 37  Tahniah boy nisa \nMoga allah permudahkn segal...          22
# 38  Ikut sebak Tahniah nisa&boy,semoga baby dlm ka...          69
# 39  Sahabat dunia akhirat touching dohh ..Aku terk...          10
